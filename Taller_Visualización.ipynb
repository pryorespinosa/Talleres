# %% [markdown]
# ## TALLER CRITICO ACERCA DE VISUALIZACIONES
# ### Auntor:Pryor Jamphiers Espinosa Muñoz
#
# >> Taller #1
# >>> Corrección de visualizaciones

# %% [markdown]
# #**Librerias**

# %%
#@title Librerias
import os
import pandas as pd 
import numpy as np
from google.colab import files
from google.colab import auth
auth.authenticate_user()
import gspread
from oauth2client.client import GoogleCredentials
# !pip install XlsxWriter
from gspread_dataframe import set_with_dataframe
import xlsxwriter
from openpyxl import Workbook
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive


auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
from google.auth import default
creds, _ = default()
gc = gspread.authorize(creds)

# Función para guardar archivos en Google Drive
from googleapiclient.discovery import build
drive_service = build('drive', 'v3')

#folder_id = '0BwwA4oUTeiV1TGRPeTVjaWRDY1E'
def save_file(nombre_archivo, folder_id):

  from googleapiclient.http import MediaFileUpload

  file_metadata = {
      'name': nombre_archivo,
      'mimeType': 'application/vnd.google-apps.spreadsheet',
      'parents': [folder_id]
  }
 
  created = drive_service.files().create(body=file_metadata,
                                       fields='id').execute()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 149 kB 5.1 MB/s
# ...

# %% [markdown]
# #**Visualización 1**

# %% [markdown]
# El siguiente grafico es una representación acerca de la situación de los pacientes que durante la pandemia tuvieron complicaciones, la representacion por un grafico de torta se divide en 6 estados las cuales son:
#
# 1.   Leve
# 2.   Fallecido
# 3.   leve
# 4.   N/A
# 5.   Moderado
# 6.   Grave

# %% [markdown]
# ![Captura1.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# archivo de: https://www.datos.gov.co/Salud-y-Protecci-n-Social/Covid-19-patients-state/ammv-2qed

# %% [markdown]
# #**Analisis**
#
# ¿Que?
#
# En la siguiente visualización se sacaron de datos abiertos generado por el DANE, estos datos provienen especificamente del area de "Salud y Proteccion social Covid-19" el cual es un seguimiento que se les hace a todas las ips del pais, para poder monitorear como vamos con los casos positivos de covid-19 y como evolucionan estos casos, la periodisidad de este estudio empieza en Marzo del 2020 y se finalizo en Mayo del 2022.
#
# En ella se adhieren diferentes variables las cuales son el tiempo de contagio, fecha de recuperación y demas, estas variables son relevantes por temas de seguimiento, este tipo de estudio va dirigido a diferentes usuarios que le pueda ayudar.
#
# ¿Porque?
#
# **Proporcionalidad/diferencias**
#  En terminos de porporcionalidad y diferencia nos referimos a la divición entre grupos de contagios, como lo son contagios en diferentes espacios, y con ello observar como podemos calcular diferenciación de población.
#  Estos datos se encuentran desagregadas por departamento, ciudad y duración del contagio.
#
#  ¿Como?
#
#  Nos vamos a una proporcionalidad dividida por estado en la que agregamos toda nuestra peridiosidad separada por diferentes colores de relación.

# %% [markdown]
# **Posibles elecciones de colores y estilo de grafica**
#
# Las marcas de estas visualizaciones son las siguientes:
#
#
#
# 1.   Area: Este area es representada en un grafico de torta en la que podemos evidenciar la categorización de la población
# 2.   Posición: En nuestra pocisión diferenciamos la elección de la grafica la cual representa un resumen de datos en nuestro estudio
# 3.   Color: en este item se diferencian los estados del usuario respecto a la definición.

# %% [markdown]
# **Reglas Generales**
#
# El objetivo es poder analizar posibles falencias y aciertos en la visualización encontrada.
#
# 1.   Grafico 3D: No aplica a esta visualización.
# 2.   Grafico 2D: Se evidencia una problematica muy grande la cual es proporción, las demas categorias se pierden en la grafica.
# 3.   Acercamiento: La visualización no deja tener ninguna interacción.
# 4.   Responde: Responde a lo solicitado de auerdo a la cantidad de variables

# %% [markdown]
# **Posibles Correcciones**
#
# Las posibles correcciones son en temas de datos, tenemos variables categoricas las cuales se repite por temas de estilo como lo es Leve por tema de mayuscula se diferencia el estado cuando es el mismo.
# Tambien podemos evidenciar datos faltantes

# %% [markdown]
# **Mejoras de la grafica**
#
#
#
# *   Respecto a mejoras de proyecto nos referimos a manejar de una manera mas facil y mejor los datos, podemos general una limpieza de datos o tambien podemos observar cuales son los datos que me generan datos duplicados o datos faltantes.
# *   La grafica no es la mejor, la elección de esta puede mejorar la idea porque podemos escoger una mejor visualización en este estudio en diferentes graficas como lo puede ser un linechart que nos pueda ayudar a observar como se comportan los estados de casos positivos respecto a un periodo determinado, si quisieramos observar en temas de porcentaje podemos pensar en un barplot que nos pueda ayudar a mirar diferencias de cifras.

# %% [markdown]
# #Visualización 2

# %% [markdown]
# **Visualización de nacimientos**
#
# En la siguiente visualización analisaremos como se estan comportando los nacimientos respecto a la educación adquirida por los padres, en ella podemos encontrar desde "SIN INFORMACIÓN" hasta una "ESPECIALIZACIÓN"

# %% [markdown]
# ![nacimientos.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# **Analisis**
#
# ¿Que?
#
# En la siguiente visualización se sacaron de datos abiertos generado por el DANE, especificamente de los  "Nacidos Vivos en el año 2016 de Guadalajara de Buga" cabe aclarar que esta grafica esta acumulada en padre y madre, no existe un filtro que nos deje mirar por caso especifico.
#  **La caracteristica del set de datos es la siguiente**:
#  Educación terminada por los padres de familia: en ella encontramos a que categoria pertenece cada uno de los padres
# **Año**
# Solo tenemos un año de muestra en el que se acumulan todos nuestra muestra.
# **CANT NACIMIENTOS**
# La cantidad de nacimientos de acuerdo al nivel educativo de los padres de familia.
#
# ¿Porque?
#
# **Escala**
# En terminos de escala se puede observar como se generan los picos dependiendo del nivel educativo alcanzado por los padres, en cada una de las metricas utilizadas se puede visualizar los colores respectivos dependiendo de cada una de las metricas estipuladas
#
#  ¿Como?
#
# Nos vamos a una escala en el grafico de area como la desagregación en el respectivo cambio de educación, sacando conclusiones pertinentes las cuales van enfocadas al numero de nacimientos que estan generando de acuerdo a los su educación.

# %% [markdown]
# **Primera impresión de la grafica**
#
# Hablamos de marcas como el analisis de la grafica o visualización.
#
#
# 1.   Area: Representamos el area desagregada por nivel educativo
# 2.   Posición: Obtenemos posición como el tamaño de cada una de las graficas representada con su respectiva variable.
# 3.   Color: Tenemos 10 dolores la cual cada una tiene su importancia.

# %% [markdown]
# **Reglas Generales**
#
# El objetivo es poder analizar posibles falencias y aciertos en la visualización encontrada.
#
# 1.   Grafico 3D
# 2.   Grafico 2D: Se evidencia una acumulación de varias graicas 2D una encima de la otra.
# 3.   Acercamiento: La visualización no deja tener ninguna interacción.
# 4.   Responde: Responde a los solicitado pero podemos obtener mejores graficas con los mismos resultados.

# %% [markdown]
# **Mejoras de la grafica**
#
#
#
# *   Primero analizemos los posibles cambios que pueden tener este grafico como lo es la selección de la paleta de colores, en ella podemos observar la difumación de las variables mas representativas para que se pueda visualisar mejor las variables que no representan tanta cantidad de datos en el estudio.
#
# *   Podriamos mejorar la elección de los datos como el medio que llevamos para observar de una mejor manera la desagregación de nacimientos por nivel educativo alcanzado por los padres de familia del infante
#
# *
